# %%
import pyspark.sql.types as T

# %%
# %run ../Utils/DBInstanceUtils.ipynb

# %%
dbi = DBInstanceUtils('treinamento_formula1')
filename = 'constructors'
extension = 'json'
file = filename + '.' + extension

schema = T.StructType([
    T.StructField("constructorId", T.IntegerType(), True),
    T.StructField("constructorRef", T.StringType(), True),
    T.StructField("name", T.StringType(), True),
    T.StructField("nationality", T.StringType(), True),
    T.StructField("url", T.StringType(), True),
])

df = dbi.sprk.read.format(extension).schema(schema).load(f'{dbi.get_filepath()}/{file}')

# %%
filename    = 'constructorsRaw'
extension   = 'delta'
file        = f'{filename}.{extension}'
dbi.set_savepath('dbfs', f'formula1/bronze/constructors', file)

# %%
#df.write.format("delta").mode("overwrite").save(dbi.get_savepath('dbfs'))
