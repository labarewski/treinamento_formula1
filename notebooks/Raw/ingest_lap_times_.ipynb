# %% [markdown]
# ## e um teste

# %%
#def retirar_nome_do_usuario(string_diretorio):
      #string_diretorio = string_diretorio.replace("file:/Workspace/Users/", "")
#file:/Workspace/Users/
#dbutils.fs.ls
#user = retirar_nome_do_usuario(dbutils.fs.ls)

# %%
# %python
def retirar_nome_do_usuario(string_diretorio):
    # Dividir a string no padrão "file:/Workspace/Users/"
    partes = string_diretorio.split("file:/Workspace/Users/")
    if len(partes) > 1:
        # Pegar a parte após "file:/Workspace/Users/" e dividir por "/"
        usuario = partes[1].split("/")[0]
        return usuario
    return None

# Especificar o diretório que você deseja listar
diretorio = "file:/Workspace/Users/user-xlvtawsmmhbc@oreilly-cloudlabs.com/treinamento_formula1/landing/lap_times/"
user = retirar_nome_do_usuario(diretorio)

# %% [markdown]
# ## o programa ta aqui:

# %%
# %python
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

# Definindo o esquema para o DataFrame
schema = StructType([
    StructField("raceId", IntegerType(), False),
    StructField("driverId", IntegerType(), True),
    StructField("lap", IntegerType(), True),
    StructField("position", IntegerType(), True),
    StructField("time", StringType(), True),
    StructField("milliseconds", IntegerType(), True)
])

# Lendo todos os arquivos CSV no diretório usando o esquema definido
try:
    lap_times_df = spark.read.format("csv") \
        .option("header", True) \
        .schema(schema) \
            #esta com um erro para achar o user
        .load("file:/Workspace/Users/{}/treinamento_formula1/landing/lap_times/*.csv".format(user))
    display(lap_times_df)
except Exception as e:
    print(e)
    pass

# %%
try:
    lap_times_df.write.format("delta").mode("overwrite").save("dbfs:/mnt/formula1/bronze/lap_times.delta")
except Exception as e:
    print(e)
    pass
