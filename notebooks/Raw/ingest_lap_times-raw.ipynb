# %%
import pyspark.sql.types as T

# %%
# %run ../Utils/DBInstanceUtils.ipynb

# %%
# %run ../Utils/ProcessingUtils.ipynb

# %%
dbi = DBInstanceUtils('treinamento_formula1')
extension = 'csv'

schema = T.StructType([
    T.StructField("raceId", T.IntegerType(), False),
    T.StructField("driverId", T.IntegerType(), True),
    T.StructField("lap", T.IntegerType(), True),
    T.StructField("position", T.IntegerType(), True),
    T.StructField("time", T.StringType(), True),
    T.StructField("milliseconds", T.IntegerType(), True)
])

# %%
df = df = (dbi.sprk.read
            .option('mode', 'FAILFAST')
            .schema(schema)
            .csv(f'{dbi.get_filepath()}/lap_times/*.csv'))

# %%
filename    = 'laptimesRaw'
extension   = 'delta'
file        = f'{filename}.{extension}'
dbi.set_savepath('dbfs', f'formula1/bronze/laptimes', file)

# %%
#df.write.format("delta").mode("overwrite").save(dbi.get_savepath('dbfs'))
